# %%
import numpy as np

# %%
print(np.__version__)
# Out:
# 1.26.4

# %%
lis=[1,2,3,"pwskills",3+5j,True,1.2]
type(lis)
# Out:
# list

# %%
arr=np.array(lis)

# %%
type(arr)
# Out:
# numpy.ndarray

# %%
arr
# Out:
# array(['1', '2', '3', 'pwskills', '(3+5j)', 'True', '1.2'], dtype='<U64')

# %%
#array stores homogenous data
l=[1,2,3,4,5,2.5]
np.array(l)
# Out:
# array([1. , 2. , 3. , 4. , 5. , 2.5])

# %%
arr.ndim
# Out:
# 1

# %%
arr1=np.array([[1,2,3],[4,5,6]])
arr1
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
arr1.ndim
# Out:
# 2
