# %%
import numpy as np
l=[1,2,3,4,1.2,True,"ashwinii"]

# %%
np.__version__
# Out:
# '1.26.4'

# %%
arr.(l)
# Out:
#   Cell In[3], line 1
#     arr.(l)
#         ^
# SyntaxError: invalid syntax

# %%
arr(l)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 arr(l)
#
# NameError: name 'arr' is not defined

# %%
arr=l

# %%
import pandas as pd
