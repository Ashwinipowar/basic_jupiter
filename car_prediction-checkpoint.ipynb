# %%
 import warnings

# %%
warnings.filterwarnings('ignore')

# %%
import pandas as pd

# %%
pd.read_csv("car data2.csv")
# Out:
#          Car Name  Year  Selling Price (in lakhs)  Present Price (in lakhs)  \
# 0            Ritz  2014                     15.00                     20.00
# 1             SX4  2013                     12.00                     18.00
# 2            Ciaz  2017                      7.25                      9.85
# 3         Wagon R  2011                      2.85                      4.15
# 4           Swift  2014                      4.60                      6.87
# 5   Vitara Brezza  2018                      9.25                      9.83
# 6            Ciaz  2015                      6.75                      8.12
# 7         S Cross  2015                      6.50                      8.61
# 8            Ciaz  2016                      8.75                      8.89
# 9            Ciaz  2015                      7.45                      8.92
# 10       Alto 800  2017                      2.85                      3.60
# ...

# %%
data=(pd.read_csv("car data2.csv"))

# %%
data
# Out:
#          Car Name  Year  Selling Price (in lakhs)  Present Price (in lakhs)  \
# 0            Ritz  2014                     15.00                     20.00
# 1             SX4  2013                     12.00                     18.00
# 2            Ciaz  2017                      7.25                      9.85
# 3         Wagon R  2011                      2.85                      4.15
# 4           Swift  2014                      4.60                      6.87
# 5   Vitara Brezza  2018                      9.25                      9.83
# 6            Ciaz  2015                      6.75                      8.12
# 7         S Cross  2015                      6.50                      8.61
# 8            Ciaz  2016                      8.75                      8.89
# 9            Ciaz  2015                      7.45                      8.92
# 10       Alto 800  2017                      2.85                      3.60
# ...

# %%
# to display top 5 rows
data.head()
# Out:
#   Car Name  Year  Selling Price (in lakhs)  Present Price (in lakhs)  \
# 0     Ritz  2014                     15.00                     20.00
# 1      SX4  2013                     12.00                     18.00
# 2     Ciaz  2017                      7.25                      9.85
# 3  Wagon R  2011                      2.85                      4.15
# 4    Swift  2014                      4.60                      6.87
#
#    Kms Driven Fuel Type Seller Type Transmission  Owner
# 0        1000    Petrol      Dealer       Manual      0
# 1        5000    Diesel      Dealer       Manual      0
# 2        6900    Petrol      Dealer       Manual      0
# 3        5200    Petrol      Dealer       Manual      0
# 4       42450    Diesel      Dealer       Manual      0

# %%
# for last 5 rows
data.tail()
# Out:
#     Car Name  Year  Selling Price (in lakhs)  Present Price (in lakhs)  \
# 39       SX4  2003                      2.25                      7.98
# 40    Baleno  2016                      5.85                      7.87
# 41  Alto K10  2014                      2.55                      3.98
# 42       SX4  2008                      1.95                      7.15
# 43     Dzire  2014                      5.50                      8.06
#
#     Kms Driven Fuel Type Seller Type Transmission  Owner
# 39       62000    Petrol      Dealer       Manual      0
# 40       24524    Petrol      Dealer    Automatic      0
# 41       46706    Petrol      Dealer       Manual      0
# 42       58000    Petrol      Dealer       Manual      0
# 43       45780    Diesel      Dealer       Manual      0

# %%
# to finding the shape of dataset means the rows and the column
data.shape
# Out:
# (44, 9)

# %%
print ("Number of rows" ,data.shape[0])
print("Number of columns" , data .shape[1])
# Out:
# Number of rows 44
# Number of columns 9

# %%
# getting info of the data set
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Car Name                  44 non-null     object
#  1   Year                      44 non-null     int64
#  2   Selling Price (in lakhs)  44 non-null     float64
#  3   Present Price (in lakhs)  44 non-null     float64
#  4   Kms Driven                44 non-null     int64
#  5   Fuel Type                 44 non-null     object
#  6   Seller Type               44 non-null     object
#  7   Transmission              44 non-null     object
#  8   Owner                     44 non-null     int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 3.2+ KB

# %%
# for cheking the null values
data.isnull()
# Out:
#     Car Name   Year  Selling Price (in lakhs)  Present Price (in lakhs)  \
# 0      False  False                     False                     False
# 1      False  False                     False                     False
# 2      False  False                     False                     False
# 3      False  False                     False                     False
# 4      False  False                     False                     False
# 5      False  False                     False                     False
# 6      False  False                     False                     False
# 7      False  False                     False                     False
# 8      False  False                     False                     False
# 9      False  False                     False                     False
# 10     False  False                     False                     False
# 11     False  False                     False                     False
# ...

# %%
data.isnull().sum()
# Out:
# Car Name                    0
# Year                        0
# Selling Price (in lakhs)    0
# Present Price (in lakhs)    0
# Kms Driven                  0
# Fuel Type                   0
# Seller Type                 0
# Transmission                0
# Owner                       0
# dtype: int64

# %%
# for getting overall statistics for the numerical columns
data.describe()
# Out:
#               Year  Selling Price (in lakhs)  Present Price (in lakhs)  \
# count    44.000000                 44.000000                 44.000000
# mean   2013.500000                  5.128409                  7.662045
# std       3.252906                  2.876335                  3.424956
# min    2003.000000                  0.350000                  2.280000
# 25%    2011.750000                  2.850000                  5.065000
# 50%    2014.000000                  4.775000                  7.725000
# 75%    2015.250000                  6.950000                  9.147500
# max    2018.000000                 15.000000                 20.000000
#
#           Kms Driven  Owner
# count      44.000000   44.0
# mean    36854.545455    0.0
# std     23729.282090    0.0
# min      1000.000000    0.0
# 25%     19699.000000    0.0
# 50%     42408.500000    0.0
# 75%     49074.750000    0.0
# max    127000.000000    0.0

# %%
# performing the data preprossesing
data.head(1)
# Out:
#   Car Name  Year  Selling Price (in lakhs)  Present Price (in lakhs)  \
# 0     Ritz  2014                      15.0                      20.0
#
#    Kms Driven Fuel Type Seller Type Transmission  Owner
# 0        1000    Petrol      Dealer       Manual      0

# %%
# by using the year column we are going to create the new feature which is the age of the car

# %%
import datetime

# %%
datetime.datetime.now()
# Out:
# datetime.datetime(2025, 1, 18, 13, 25, 17, 301891)

# %%
date_time=(datetime.datetime.now())

# %%
# we are intrested in age o f the car as per the current year

# %%
date_time.year-data['Year']
# Out:
# 0     11
# 1     12
# 2      8
# 3     14
# 4     11
# 5      7
# 6     10
# 7     10
# 8      9
# 9     10
# 10     8
# 11    10
# 12    10
# 13    10
# 14    16
# 15     9
# 16    10
# 17     9
# 18    10
# 19    14
# 20     9
# 21     8
# 22    14
# 23    11
# 24    12
# 25    14
# 26    12
# 27     8
# 28    15
# 29    10
# 30    13
# 31    14
# 32    11
# 33    11
# 34    11
# 35    14
# 36    10
# 37    22
# 38     9
# 39    22
# 40     9
# 41    11
# 42    17
# 43    11
# Name: Year, dtype: int64

# %%
data['Age']=date_time.year-data['Year']

# %%
data.head()
# Out:
#   Car Name  Year  Selling Price (in lakhs)  Present Price (in lakhs)  \
# 0     Ritz  2014                     15.00                     20.00
# 1      SX4  2013                     12.00                     18.00
# 2     Ciaz  2017                      7.25                      9.85
# 3  Wagon R  2011                      2.85                      4.15
# 4    Swift  2014                      4.60                      6.87
#
#    Kms Driven Fuel Type Seller Type Transmission  Owner  Age
# 0        1000    Petrol      Dealer       Manual      0   11
# 1        5000    Diesel      Dealer       Manual      0   12
# 2        6900    Petrol      Dealer       Manual      0    8
# 3        5200    Petrol      Dealer       Manual      0   14
# 4       42450    Diesel      Dealer       Manual      0   11

# %%
#removal of the year column
data.drop('Year' ,axis=1,inplace=True)

# %%
data
# Out:
#          Car Name  Selling Price (in lakhs)  Present Price (in lakhs)  \
# 0            Ritz                     15.00                     20.00
# 1             SX4                     12.00                     18.00
# 2            Ciaz                      7.25                      9.85
# 3         Wagon R                      2.85                      4.15
# 4           Swift                      4.60                      6.87
# 5   Vitara Brezza                      9.25                      9.83
# 6            Ciaz                      6.75                      8.12
# 7         S Cross                      6.50                      8.61
# 8            Ciaz                      8.75                      8.89
# 9            Ciaz                      7.45                      8.92
# 10       Alto 800                      2.85                      3.60
# 11           Ciaz                      6.85                     10.38
# ...

# %%
# outlier removal
import seaborn as sns

# %%
# !pip install seaborn

# %%
sns.boxplot(data['Selling Price (in lakhs)'])
# Out:
# <Axes: ylabel='Selling Price (in lakhs)'>

# %%
# here we can see the two points are far away from the actual data soo we are goint to call them as the outlier
data['Selling Price (in lakhs)']
# Out:
# 0     15.00
# 1     12.00
# 2      7.25
# 3      2.85
# 4      4.60
# 5      9.25
# 6      6.75
# 7      6.50
# 8      8.75
# 9      7.45
# 10     2.85
# 11     6.85
# 12     7.50
# 13     6.10
# 14     2.25
# 15     7.75
# 16     7.25
# 17     7.75
# 18     3.25
# 19     2.65
# 20     2.85
# 21     4.90
# 22     4.40
# 23     2.50
# 24     2.90
# 25     3.00
# 26     4.15
# 27     6.00
# 28     1.95
# 29     7.45
# 30     3.10
# 31     2.35
# 32     4.95
# 33     6.00
# 34     5.50
# 35     2.95
# 36     4.65
# 37     0.35
# 38     3.00
# 39     2.25
# 40     5.85
# 41     2.55
# 42     1.95
# 43     5.50
# Name: Selling Price (in lakhs), dtype: float64

# %%
# sorted data in decending order
sorted(data['Selling Price (in lakhs)'],reverse=True)
# Out:
# [15.0,
#  12.0,
#  9.25,
#  8.75,
#  7.75,
#  7.75,
#  7.5,
#  7.45,
#  7.45,
#  7.25,
#  7.25,
#  6.85,
#  6.75,
#  6.5,
#  6.1,
#  6.0,
#  6.0,
#  5.85,
#  5.5,
#  5.5,
#  4.95,
#  4.9,
#  4.65,
#  4.6,
#  4.4,
#  4.15,
#  3.25,
#  3.1,
#  3.0,
#  3.0,
#  2.95,
#  2.9,
#  2.85,
#  2.85,
#  2.85,
#  2.65,
#  2.55,
#  2.5,
#  2.35,
#  2.25,
#  2.25,
#  1.95,
#  1.95,
#  0.35]

# %%
(data['Selling Price (in lakhs)']>=12.0) & (data['Selling Price (in lakhs)']<=15.0)
# Out:
# 0      True
# 1      True
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# Name: Selling Price (in lakhs), dtype: bool

# %%
data[(data['Selling Price (in lakhs)']>=12.0 ) & (data['Selling Price (in lakhs)']<=15.0)]
# these are the outlires
# Out:
#   Car Name  Selling Price (in lakhs)  Present Price (in lakhs)  Kms Driven  \
# 0     Ritz                      15.0                      20.0        1000
# 1      SX4                      12.0                      18.0        5000
#
#   Fuel Type Seller Type Transmission  Owner  Age
# 0    Petrol      Dealer       Manual      0   11
# 1    Diesel      Dealer       Manual      0   12

# %%
# we rae going to remove this
data=data[~(data['Selling Price (in lakhs)']>=12.0) & (data['Selling Price (in lakhs)']<=15.0)]

# %%
data.shape
# the actual shape was 4340 now there two null values are the removed
# Out:
# (42, 9)

# %%
# here we are going to perform encoding for our data set
data.head(1)
# Out:
#   Car Name  Selling Price (in lakhs)  Present Price (in lakhs)  Kms Driven  \
# 2     Ciaz                      7.25                      9.85        6900
#
#    Fuel Type  Seller Type  Transmission  Owner  Age  owner
# 2        NaN          NaN           NaN      0    8      0

# %%
data["owner"]=0

# %%
data["Fuel Type"]=0

# %%
data["Seller Type"]=0

# %%
data["Transmission"]=0

# %%
data
# Out:
#          Car Name  Selling Price (in lakhs)  Present Price (in lakhs)  \
# 2            Ciaz                      7.25                      9.85
# 3         Wagon R                      2.85                      4.15
# 4           Swift                      4.60                      6.87
# 5   Vitara Brezza                      9.25                      9.83
# 6            Ciaz                      6.75                      8.12
# 7         S Cross                      6.50                      8.61
# 8            Ciaz                      8.75                      8.89
# 9            Ciaz                      7.45                      8.92
# 10       Alto 800                      2.85                      3.60
# 11           Ciaz                      6.85                     10.38
# 12           Ciaz                      7.50                      9.94
# 13         Ertiga                      6.10                      7.71
# ...

# %%
# the numerical vlues
data['Fuel Type'].unique()
# Out:
# array([0], dtype=int64)

# %%
data['Fuel Type']= data['Fuel Type'].map({'petrol':0, 'diseal':1, 'cng':2})

# %%
data['Fuel Type'].unique()
# Out:
# array([nan])

# %%
data['Seller Type'].unique()
# Out:
# array([0], dtype=int64)

# %%
data['Seller Type']=data['Seller Type'].map({'dealer':0, 'indivisual':1})

# %%
data['Transmission'].unique()
# Out:
# array([0], dtype=int64)

# %%
data['Transmission']= data ['Transmission'].map({'manual':0, 'Automatic':1})

# %%
data.head()
# Out:
#         Car Name  Selling Price (in lakhs)  Present Price (in lakhs)  \
# 2           Ciaz                      7.25                      9.85
# 3        Wagon R                      2.85                      4.15
# 4          Swift                      4.60                      6.87
# 5  Vitara Brezza                      9.25                      9.83
# 6           Ciaz                      6.75                      8.12
#
#    Kms Driven  Fuel Type  Seller Type  Transmission  Owner  Age  owner
# 2        6900        NaN          NaN           NaN      0    8      0
# 3        5200        NaN          NaN           NaN      0   14      0
# 4       42450        NaN          NaN           NaN      0   11      0
# 5        2071        NaN          NaN           NaN      0    7      0
# 6       18796        NaN          NaN           NaN      0   10      0

# %%
x=data.drop(['Car Name','Selling Price (in lakhs)'],axis=1)
y=data['Selling Price (in lakhs)']

# %%
data['Selling Price (in lakhs)'].mean() # this done for the putting value in
# Out:
# 4.729761904761904

# %%
data['Selling Price (in lakhs)'].fillna(data['Selling Price (in lakhs)'].mean())
# Out:
# 2     7.25
# 3     2.85
# 4     4.60
# 5     9.25
# 6     6.75
# 7     6.50
# 8     8.75
# 9     7.45
# 10    2.85
# 11    6.85
# 12    7.50
# 13    6.10
# 14    2.25
# 15    7.75
# 16    7.25
# 17    7.75
# 18    3.25
# 19    2.65
# 20    2.85
# 21    4.90
# 22    4.40
# 23    2.50
# 24    2.90
# 25    3.00
# 26    4.15
# 27    6.00
# 28    1.95
# 29    7.45
# 30    3.10
# 31    2.35
# 32    4.95
# 33    6.00
# 34    5.50
# 35    2.95
# 36    4.65
# 37    0.35
# 38    3.00
# 39    2.25
# 40    5.85
# 41    2.55
# 42    1.95
# 43    5.50
# Name: Selling Price (in lakhs), dtype: float64

# %%
x=data.drop(['Car Name','Selling Price (in lakhs)'],axis=1)
y=data['Selling Price (in lakhs)']

# %%
x
# hare is our indeipendent variables
# Out:
#     Present Price (in lakhs)  Kms Driven  Fuel Type  Seller Type  \
# 2                       9.85        6900        NaN          NaN
# 3                       4.15        5200        NaN          NaN
# 4                       6.87       42450        NaN          NaN
# 5                       9.83        2071        NaN          NaN
# 6                       8.12       18796        NaN          NaN
# 7                       8.61       33429        NaN          NaN
# 8                       8.89       20273        NaN          NaN
# 9                       8.92       42367        NaN          NaN
# 10                      3.60        2135        NaN          NaN
# 11                     10.38       51000        NaN          NaN
# 12                      9.94       15000        NaN          NaN
# 13                      7.71       26000        NaN          NaN
# 14                      7.21       77427        NaN          NaN
# ...

# %%
y
# here is then having the selling price , and these are the dependent vraiables
# Out:
# 2     7.25
# 3     2.85
# 4     4.60
# 5     9.25
# 6     6.75
# 7     6.50
# 8     8.75
# 9     7.45
# 10    2.85
# 11    6.85
# 12    7.50
# 13    6.10
# 14    2.25
# 15    7.75
# 16    7.25
# 17    7.75
# 18    3.25
# 19    2.65
# 20    2.85
# 21    4.90
# 22    4.40
# 23    2.50
# 24    2.90
# 25    3.00
# 26    4.15
# 27    6.00
# 28    1.95
# 29    7.45
# 30    3.10
# 31    2.35
# 32    4.95
# 33    6.00
# 34    5.50
# 35    2.95
# 36    4.65
# 37    0.35
# 38    3.00
# 39    2.25
# 40    5.85
# 41    2.55
# 42    1.95
# 43    5.50
# Name: Selling Price (in lakhs), dtype: float64

# %%
#spitting the dataset into the training set and the testing set
from sklearn.model_selection import train_test_split

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [raw]
# x_train,x_test,y_train,y_test=train_test_split( x,y,test_size=0.20,random_state=42)

# %%
# here we are going to import our models
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor

# %%
x_train,x_test,y_train,y_test=train_test_split( x,y,test_size=0.20,random_state=42)

# %%
x=data.drop(['Car Name','Selling Price (in lakhs)'],axis=1)
y=data['Selling Price (in lakhs)']

# %%
x
# Out:
#     Present Price (in lakhs)  Kms Driven  Fuel Type  Seller Type  \
# 2                       9.85        6900        NaN          NaN
# 3                       4.15        5200        NaN          NaN
# 4                       6.87       42450        NaN          NaN
# 5                       9.83        2071        NaN          NaN
# 6                       8.12       18796        NaN          NaN
# 7                       8.61       33429        NaN          NaN
# 8                       8.89       20273        NaN          NaN
# 9                       8.92       42367        NaN          NaN
# 10                      3.60        2135        NaN          NaN
# 11                     10.38       51000        NaN          NaN
# 12                      9.94       15000        NaN          NaN
# 13                      7.71       26000        NaN          NaN
# 14                      7.21       77427        NaN          NaN
# ...

# %%
x.shape
# Out:
# (42, 8)

# %%
y.shape
# Out:
# (42,)

# %%
print(x_train.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 33 entries, 8 to 40
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Present Price (in lakhs)  33 non-null     float64
#  1   Kms Driven                33 non-null     int64
#  2   Fuel Type                 0 non-null      float64
#  3   Seller Type               0 non-null      float64
#  4   Transmission              0 non-null      float64
#  5   Owner                     33 non-null     int64
#  6   Age                       33 non-null     int64
#  7   owner                     33 non-null     int64
# dtypes: float64(4), int64(4)
# memory usage: 2.3 KB
# None

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)

# %%
pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# now machine learnig algorithm on our training sets
lr=LinearRegression()
lr.fit(x_train,y_train)
 
rf=RandomForestRegressor()
rf.fit(x_train,y_train)

xgb=GradientBoostingRegressor()
xgb.fit(x_train,y_train)

xg=XGBRegressor()
xg.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[245], line 3
#       1 # now machine learnig algorithm on our training sets
#       2 lr=LinearRegression()
# ----> 3 lr.fit(x_train,y_train)
#       5 rf=RandomForestRegressor()
#       6 rf.fit(x_train,y_train)
#
# File ~\Documents\Custom Office Templates\Lib\site-packages\sklearn\base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File ~\Documents\Custom Office Templates\Lib\site-packages\sklearn\linear_model\_base.py:601, in LinearRegression.fit(self, X, y, sample_weight)
# ...
