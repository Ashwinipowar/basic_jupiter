# %%
 import warnings

# %%
warnings.filterwarnings('ignore')

# %%
import pandas as pd

# %%
pd.read_csv("car_data.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 pd.read_csv("car_data.csv")
#
# File ~\Documents\Custom Office Templates\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\Documents\Custom Office Templates\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\Documents\Custom Office Templates\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\Documents\Custom Office Templates\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~\Documents\Custom Office Templates\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'car_data.csv'

# %%
data=(pd.read_csv("car_data.csv"))

# %%
data

# %%
# to display top 5 rows
data.head()

# %%
# for last 5 rows
data.tail()

# %%
# to finding the shape of dataset means the rows and the column
data.shape

# %%
print ("Number of rows" ,data.shape[0])
print("Number of columns" , data .shape[1])

# %%
# getting info of the data set
data.info()

# %%
# for cheking the null values
data.isnull()

# %%
data.isnull().sum()

# %%
# for getting overall statistics for the numerical columns
data.describe()

# %%
# performing the data preprossesing
data.head(1)

# %%
# by using the year column we are going to create the new feature which is the age of the car

# %%
import datetime

# %%
datetime.datetime.now()

# %%
date_time=(datetime.datetime.now())

# %%
# we are intrested in age o f the car as per the current year

# %%
date_time.year-data['Year']

# %%
data['Age']=date_time.year-data['Year']

# %%
data.head()

# %%
#removal of the year column
data.drop('Year' ,axis=1,inplace=True)

# %%
data

# %%
# outlier removal
import seaborn as sns

# %%
# !pip install seaborn

# %%
sns.boxplot(data['Selling_Price'])

# %%
# here we can see the two points are far away from the actual data soo we are goint to call them as the outlier
data['Selling_Price']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 # here we can see the two points are far away from the actual data soo we are goint to call them as the outlier
# ----> 2 data['Selling_Price']
#
# NameError: name 'data' is not defined

# %%
# sorted data in decending order
sorted(data['Selling_Price'],reverse=True)

# %%
(data['Selling_Price']>=33.0) & (data['Selling_Price']<=35.0)

# %%
# we rae going to remove this
data=data[~(data['Selling_Price']>=33.0) & (data['Selling_Price']<=35.0)]

# %%
data.shape
# the actual shape was 4340 now there two null values are the removed

# %%
# here we are going to perform encoding for our data set
data.head(1)

# %%
# here we converted string to flot values

# %%
# the numerical vlues
data['Fuel_Type'].unique()

# %%
data['Fuel_Type']= data['Fuel_Type'].map({'Petrol':0, 'Diesel':1, 'CNG':2})

# %%
data['Fuel_Type'].unique()

# %%
data['Seller_Type'].unique()

# %%
data['Seller_Type']=data['Seller_Type'].map({'Dealer':0, 'Individual':1})

# %%
data['Seller_Type'].unique()

# %%
data['Transmission'].unique()

# %%
data['Transmission']= data ['Transmission'].map({'Manual':0, 'Automatic':1})

# %%
data['Transmission'].unique()

# %%
data.head()

# %%
x=data.drop(['Car_Name','Selling_Price'],axis=1)
y=data['Selling_Price']

# %%
x
# hare is our indeipendent variables

# %%
y
# here is then having the selling price , and these are the dependent vraiables

# %%
# %pip install xgboost
#pip install scikit-learn==1.1.3  # Or an earlier version

# %%
#spitting the dataset into the training set and the testing set
from sklearn.model_selection import train_test_split
#pip install scikit-lear
# %pip install scikit-learn==1.2.2

# %%
x_train,x_test,y_train,y_test=train_test_split( x,y,test_size=0.20,random_state=42)

# %%
data.head()

# %%
import xgboost

# %%
# !pip install xgboost

# %%
# here we are going to import our models
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)

rf=RandomForestRegressor()
rf.fit(x_train,y_train)

xgb=GradientBoostingRegressor()
xgb.fit(x_train,y_train)

xg=XGBRegressor()
xg.fit(x_train,y_train)
