# %%
import pandas as pd

# %%
pd.read_csv("people-100.new.csv")
# Out:
#     Index          User Id First Name  Last Name  age      Sex  \
# 0       1  88F7B33d2bcf9f5     Shelby    Terrell    12    Male
# 1       2  f90cD3E76f1A9b9    Phillip    Summers    45  Female
# 2       3  DbeAb8CcdfeFC2c   Kristine     Travis    34    Male
# 3       4  A31Bee3c201ef58    Yesenia   Martinez    23    Male
# 4       5  1bA7A3dc874da3c       Lori       Todd    56    Male
# ..    ...              ...        ...        ...   ...     ...
# 95     96  5eFda7caAeB260E     Dennis     Barnes    64  Female
# 96     97  CCbFce93d3720bE      Steve  Patterson    34  Female
# 97     98  2fEc528aFAF0b69     Wesley       Bray    34    Male
# 98     99  Adc7ad9B6e4A1Fe     Summer   Oconnell    22  Female
# 99    100  b8D0aD3490FC7e1     Mariah    Bernard    21    Male
#
#                          Email                   Phone Date of birth  \
# 0         elijah57@example.net  001-084-906-7849x73518    26-10-1945
# ...

# %%
df=(pd.read_csv("people-100.new.csv"))

# %%
df
# Out:
#     Index          User Id First Name  Last Name  age      Sex  \
# 0       1  88F7B33d2bcf9f5     Shelby    Terrell    12    Male
# 1       2  f90cD3E76f1A9b9    Phillip    Summers    45  Female
# 2       3  DbeAb8CcdfeFC2c   Kristine     Travis    34    Male
# 3       4  A31Bee3c201ef58    Yesenia   Martinez    23    Male
# 4       5  1bA7A3dc874da3c       Lori       Todd    56    Male
# ..    ...              ...        ...        ...   ...     ...
# 95     96  5eFda7caAeB260E     Dennis     Barnes    64  Female
# 96     97  CCbFce93d3720bE      Steve  Patterson    34  Female
# 97     98  2fEc528aFAF0b69     Wesley       Bray    34    Male
# 98     99  Adc7ad9B6e4A1Fe     Summer   Oconnell    22  Female
# 99    100  b8D0aD3490FC7e1     Mariah    Bernard    21    Male
#
#                          Email                   Phone Date of birth  \
# 0         elijah57@example.net  001-084-906-7849x73518    26-10-1945
# ...

# %%
df.describe()
# Out:
#             Index        age
# count  100.000000  100.000000
# mean    50.500000   53.970000
# std     29.011492   24.842719
# min      1.000000   10.000000
# 25%     25.750000   33.750000
# 50%     50.500000   53.500000
# 75%     75.250000   74.250000
# max    100.000000   99.000000

# %%
# first 5 rows
df.head()
# Out:
#    Index          User Id First Name Last Name  age      Sex  \
# 0      1  88F7B33d2bcf9f5     Shelby   Terrell    12    Male
# 1      2  f90cD3E76f1A9b9    Phillip   Summers    45  Female
# 2      3  DbeAb8CcdfeFC2c   Kristine    Travis    34    Male
# 3      4  A31Bee3c201ef58    Yesenia  Martinez    23    Male
# 4      5  1bA7A3dc874da3c       Lori      Todd    56    Male
#
#                         Email                   Phone Date of birth  \
# 0        elijah57@example.net  001-084-906-7849x73518    26-10-1945
# 1       bethany14@example.com       214.112.6044x4913    24-03-1910
# 2       bthompson@example.com            277.609.7938    02-07-1992
# 3   kaitlinkaiser@example.com            584.094.6111    03-08-2017
# 4  buchananmanuel@example.net       689-207-3558x7233    01-12-1938
#
#             Job Title
# 0     Games developer
# 1      Phytotherapist
# 2           Homeopath
# 3   Market researcher
# 4  Veterinary surgeon

# %%
# last 5 rows
df.tail()
# Out:
#     Index          User Id First Name  Last Name  age      Sex  \
# 95     96  5eFda7caAeB260E     Dennis     Barnes    64  Female
# 96     97  CCbFce93d3720bE      Steve  Patterson    34  Female
# 97     98  2fEc528aFAF0b69     Wesley       Bray    34    Male
# 98     99  Adc7ad9B6e4A1Fe     Summer   Oconnell    22  Female
# 99    100  b8D0aD3490FC7e1     Mariah    Bernard    21    Male
#
#                          Email                 Phone Date of birth  \
# 95         bmartin@example.org  001-095-524-2112x257    30-07-1954
# 96       latasha46@example.net      001-865-478-5157    29-04-1932
# 97        regina11@example.org    995-542-3004x76800    28-12-1994
# 98  alexiscantrell@example.org  001-273-685-6932x092    12-04-2012
# 99       pcopeland@example.org   (341)594-6554x44657    15-11-2016
#
#                 Job Title
# 95      Software engineer
# 96              Barrister
# 97         Police officer
# 98   Broadcast journalist
# 99  IT sales professional

# %%
#show rows and the column
df.shape
# Out:
# (100, 10)

# %%
# to check the data type
df.dtypes
# Out:
# Index             int64
# User Id          object
# First Name       object
# Last Name        object
# age               int64
# Sex              object
# Email            object
# Phone            object
# Date of birth    object
# Job Title        object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Index          100 non-null    int64
#  1   User Id        100 non-null    object
#  2   First Name     100 non-null    object
#  3   Last Name      100 non-null    object
#  4   age            100 non-null    int64
#  5   Sex            100 non-null    object
#  6   Email          100 non-null    object
#  7   Phone          100 non-null    object
#  8   Date of birth  100 non-null    object
#  9   Job Title      100 non-null    object
# dtypes: int64(2), object(8)
# memory usage: 7.9+ KB

# %%
df[0:100:2]
# Out:
#     Index          User Id  First Name   Last Name  age      Sex  \
# 0       1  88F7B33d2bcf9f5      Shelby     Terrell    12    Male
# 2       3  DbeAb8CcdfeFC2c    Kristine      Travis    34    Male
# 4       5  1bA7A3dc874da3c        Lori        Todd    56    Male
# 6       7  bE9EEf34cB72AF7   Katherine        Buck    15  Female
# 8       9  baDcC4DeefD8dEB        Dave     Farrell    89    Male
# 10     11  BF0BbA03C29Bb3b      Sheila        Ross    23  Female
# 12     13  C03fDADdAadAdCe       Mandy       Blake    55    Male
# 14     15  1F0B7D65A00DAF9     Crystal      Farmer    77    Male
# 16     17  D6dbA5308fEC4BC     Maurice      Rangel    99    Male
# 18     19  7F7E1BAcb0C9AFf       Alvin        Paul    33    Male
# 20     21  b31D271F8c200AB  Jacqueline      Norton    18  Female
# 22     23  cBbBcA0FCA3C4Bc       Randy      Barnes    30    Male
# 24     25  c5B09fb33e8bA0A      Alfred      Mcneil    53  Female
# ...

# %%
df[0:100:5]
# Out:
#     Index          User Id  First Name   Last Name  age      Sex  \
# 0       1  88F7B33d2bcf9f5      Shelby     Terrell    12    Male
# 5       6  bfDD7CDEF5D865B        Erin         Day    78    Male
# 10     11  BF0BbA03C29Bb3b      Sheila        Ross    23  Female
# 15     16  50Bb061cB30B461      Thomas      Knight    88  Female
# 20     21  b31D271F8c200AB  Jacqueline      Norton    18  Female
# 25     26  c9F2282C40BEC1E        Sean      Levine    64    Male
# 30     31  5d2feAfbdCAA6B5      Isaiah     Camacho    20  Female
# 35     36  035eff50B9A0F24      Melody        Cook    80    Male
# 40     41  7D0AcBF6CCac3fd     Matthew       Stone    62  Female
# 45     46  6bFcfc3cc1BC6B4       Haley        Pugh    35  Female
# 50     51  eA3fDd79BE9f0E7       Heidi     Escobar    91  Female
# 55     56  D8bF5Ab2b98caff   Mackenzie       Rocha    69  Female
# 60     61  bB9e49E506F65ed       Shari   Daugherty    48    Male
# ...

# %%
# access rows and the column of dataframe
df.loc[0:3] # print 0 to 3
# Out:
#    Index          User Id First Name Last Name  age      Sex  \
# 0      1  88F7B33d2bcf9f5     Shelby   Terrell    12    Male
# 1      2  f90cD3E76f1A9b9    Phillip   Summers    45  Female
# 2      3  DbeAb8CcdfeFC2c   Kristine    Travis    34    Male
# 3      4  A31Bee3c201ef58    Yesenia  Martinez    23    Male
#
#                        Email                   Phone Date of birth  \
# 0       elijah57@example.net  001-084-906-7849x73518    26-10-1945
# 1      bethany14@example.com       214.112.6044x4913    24-03-1910
# 2      bthompson@example.com            277.609.7938    02-07-1992
# 3  kaitlinkaiser@example.com            584.094.6111    03-08-2017
#
#            Job Title
# 0    Games developer
# 1     Phytotherapist
# 2          Homeopath
# 3  Market researcher

# %%
df.iloc[0:3] # print the 0 to 2
# Out:
#    Index          User Id First Name Last Name  age      Sex  \
# 0      1  88F7B33d2bcf9f5     Shelby   Terrell    12    Male
# 1      2  f90cD3E76f1A9b9    Phillip   Summers    45  Female
# 2      3  DbeAb8CcdfeFC2c   Kristine    Travis    34    Male
#
#                    Email                   Phone Date of birth  \
# 0   elijah57@example.net  001-084-906-7849x73518    26-10-1945
# 1  bethany14@example.com       214.112.6044x4913    24-03-1910
# 2  bthompson@example.com            277.609.7938    02-07-1992
#
#          Job Title
# 0  Games developer
# 1   Phytotherapist
# 2        Homeopath

# %%
# when wants a pertucular index and perticular column
df.loc[0:3,["Sex","Email"]]
# Out:
#       Sex                      Email
# 0    Male       elijah57@example.net
# 1  Female      bethany14@example.com
# 2    Male      bthompson@example.com
# 3    Male  kaitlinkaiser@example.com

# %%
df.iloc[0:3,["Sex","Email"]]
## when we add the column name with  the iloc it will throw an error
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 df.iloc[0:3,["Sex","Email"]]
#
# File ~\Documents\Custom Office Templates\Lib\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File ~\Documents\Custom Office Templates\Lib\site-packages\pandas\core\indexing.py:1690, in _iLocIndexer._getitem_tuple(self, tup)
#    1689 def _getitem_tuple(self, tup: tuple):
# -> 1690     tup = self._validate_tuple_indexer(tup)
#    1691     with suppress(IndexingError):
#    1692         return self._getitem_lowerdim(tup)
#
# ...

# %%
# when wants to access the three to six column then we can access them by their indexing also
df.iloc[0:3,5:7] # its indexing of the column5:7 and 0:3 is the no. ofrows
# iloc alwaya requires the python internal indexing

# %%
df['Job Title'][2:5]

# %%
list(df['Job Title'][2:5])

# %%
pd.Series

# %%
# here chnage the name of the indexing
s=pd.Series(list(df['Job Title'][2:5]), index =['a','b','c'])

# %%
s
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 s
#
# NameError: name 's' is not defined

# %%
s1=pd.Series(list(df['Job Title'][5:8]))

# %%
s1
# Out:
# 0    Waste management officer
# 1        Intelligence analyst
# 2              Hydrogeologist
# dtype: object

# %%
"siya"+"rohit"# concate function
# Out:
# 'siyarohit'

# %%
# series with diff indexing and dataframe can not be concatenated using "+"
s+s1 #.......here having the diff type of concate if the same type will be there then there will not be the nan value
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 2
#       1 # series with diff indexing and dataframe can not be concatenated using "+"
# ----> 2 s+s1
#
# NameError: name 's' is not defined

# %%
# if you keep the indexes some , then for  series concatination can happen
s1=pd.Series(list(df['Job Title'][5:8]),index =['a','b','c']) 
s1
# Out:
# a    Waste management officer
# b        Intelligence analyst
# c              Hydrogeologist
# dtype: object

# %%
s=pd.Series(list(df['Job Title'][2:5]), index =['a','b','c'])
s
# Out:
# a             Homeopath
# b     Market researcher
# c    Veterinary surgeon
# dtype: object

# %%
# now you can see the both having the same indexing here which id a, b, c now we can concatinate here
# here it added both the data together as you can see hmeopath and the waste managmnet....
s+s1 # thats why here not showing the nan values
# Out:
# a        HomeopathWaste management officer
# b    Market researcherIntelligence analyst
# c         Veterinary surgeonHydrogeologist
# dtype: object

# %%
# when wants  to drop  the one column
# only put--df.drop("sex") 
#it will thrw an error for that need to do , # YOU can see here not having the column og the sex
df.drop('Sex', axis=1)
# Out:
#     Index          User Id First Name  Last Name  age   \
# 0       1  88F7B33d2bcf9f5     Shelby    Terrell    12
# 1       2  f90cD3E76f1A9b9    Phillip    Summers    45
# 2       3  DbeAb8CcdfeFC2c   Kristine     Travis    34
# 3       4  A31Bee3c201ef58    Yesenia   Martinez    23
# 4       5  1bA7A3dc874da3c       Lori       Todd    56
# ..    ...              ...        ...        ...   ...
# 95     96  5eFda7caAeB260E     Dennis     Barnes    64
# 96     97  CCbFce93d3720bE      Steve  Patterson    34
# 97     98  2fEc528aFAF0b69     Wesley       Bray    34
# 98     99  Adc7ad9B6e4A1Fe     Summer   Oconnell    22
# 99    100  b8D0aD3490FC7e1     Mariah    Bernard    21
#
#                          Email                   Phone Date of birth  \
# 0         elijah57@example.net  001-084-906-7849x73518    26-10-1945
# 1        bethany14@example.com       214.112.6044x4913    24-03-1910
# 2        bthompson@example.com            277.609.7938    02-07-1992
# ...

# %%
df 
# when you pass original data frame then you can see it here also its not deleted from the original dataframe
# Out:
#     Index          User Id First Name  Last Name  age      Sex  \
# 0       1  88F7B33d2bcf9f5     Shelby    Terrell    12    Male
# 1       2  f90cD3E76f1A9b9    Phillip    Summers    45  Female
# 2       3  DbeAb8CcdfeFC2c   Kristine     Travis    34    Male
# 3       4  A31Bee3c201ef58    Yesenia   Martinez    23    Male
# 4       5  1bA7A3dc874da3c       Lori       Todd    56    Male
# ..    ...              ...        ...        ...   ...     ...
# 95     96  5eFda7caAeB260E     Dennis     Barnes    64  Female
# 96     97  CCbFce93d3720bE      Steve  Patterson    34  Female
# 97     98  2fEc528aFAF0b69     Wesley       Bray    34    Male
# 98     99  Adc7ad9B6e4A1Fe     Summer   Oconnell    22  Female
# 99    100  b8D0aD3490FC7e1     Mariah    Bernard    21    Male
#
#                          Email                   Phone Date of birth  \
# 0         elijah57@example.net  001-084-906-7849x73518    26-10-1945
# ...

# %%
# when to wanna delete from the original column ( columns)
df.drop('Sex', axis=1 , inplace=True)

# %%
df
# now you can see here the not having the sex column it deleted from the original dataframe
# Out:
#     Index          User Id First Name  Last Name  age   \
# 0       1  88F7B33d2bcf9f5     Shelby    Terrell    12
# 1       2  f90cD3E76f1A9b9    Phillip    Summers    45
# 2       3  DbeAb8CcdfeFC2c   Kristine     Travis    34
# 3       4  A31Bee3c201ef58    Yesenia   Martinez    23
# 4       5  1bA7A3dc874da3c       Lori       Todd    56
# ..    ...              ...        ...        ...   ...
# 95     96  5eFda7caAeB260E     Dennis     Barnes    64
# 96     97  CCbFce93d3720bE      Steve  Patterson    34
# 97     98  2fEc528aFAF0b69     Wesley       Bray    34
# 98     99  Adc7ad9B6e4A1Fe     Summer   Oconnell    22
# 99    100  b8D0aD3490FC7e1     Mariah    Bernard    21
#
#                          Email                   Phone Date of birth  \
# 0         elijah57@example.net  001-084-906-7849x73518    26-10-1945
# 1        bethany14@example.com       214.112.6044x4913    24-03-1910
# 2        bthompson@example.com            277.609.7938    02-07-1992
# ...

# %%
#axis=1 means the drop from columns, " inplace "= true   means to modify form the original dataframe
# axis=0 means drop from rows

# %%
# if we wanna drop a row

# %%
df
# Out:
#     Index          User Id First Name  Last Name  age   \
# 0       1  88F7B33d2bcf9f5     Shelby    Terrell    12
# 1       2  f90cD3E76f1A9b9    Phillip    Summers    45
# 2       3  DbeAb8CcdfeFC2c   Kristine     Travis    34
# 3       4  A31Bee3c201ef58    Yesenia   Martinez    23
# 4       5  1bA7A3dc874da3c       Lori       Todd    56
# ..    ...              ...        ...        ...   ...
# 95     96  5eFda7caAeB260E     Dennis     Barnes    64
# 96     97  CCbFce93d3720bE      Steve  Patterson    34
# 97     98  2fEc528aFAF0b69     Wesley       Bray    34
# 98     99  Adc7ad9B6e4A1Fe     Summer   Oconnell    22
# 99    100  b8D0aD3490FC7e1     Mariah    Bernard    21
#
#                          Email                   Phone Date of birth  \
# 0         elijah57@example.net  001-084-906-7849x73518    26-10-1945
# 1        bethany14@example.com       214.112.6044x4913    24-03-1910
# 2        bthompson@example.com            277.609.7938    02-07-1992
# ...

# %%
df.drop(5,inplace=True)  #here is drop the row of 5 no.

# %%
df
# Out:
#     Index          User Id First Name  Last Name  age   \
# 0       1  88F7B33d2bcf9f5     Shelby    Terrell    12
# 1       2  f90cD3E76f1A9b9    Phillip    Summers    45
# 2       3  DbeAb8CcdfeFC2c   Kristine     Travis    34
# 3       4  A31Bee3c201ef58    Yesenia   Martinez    23
# 4       5  1bA7A3dc874da3c       Lori       Todd    56
# ..    ...              ...        ...        ...   ...
# 95     96  5eFda7caAeB260E     Dennis     Barnes    64
# 96     97  CCbFce93d3720bE      Steve  Patterson    34
# 97     98  2fEc528aFAF0b69     Wesley       Bray    34
# 98     99  Adc7ad9B6e4A1Fe     Summer   Oconnell    22
# 99    100  b8D0aD3490FC7e1     Mariah    Bernard    21
#
#                          Email                   Phone Date of birth  \
# 0         elijah57@example.net  001-084-906-7849x73518    26-10-1945
# 1        bethany14@example.com       214.112.6044x4913    24-03-1910
# 2        bthompson@example.com            277.609.7938    02-07-1992
# ...

# %%
df.reset_index(drop=True) # make this as it  original
# Out:
#     Index          User Id First Name  Last Name  age   \
# 0       1  88F7B33d2bcf9f5     Shelby    Terrell    12
# 1       2  f90cD3E76f1A9b9    Phillip    Summers    45
# 2       3  DbeAb8CcdfeFC2c   Kristine     Travis    34
# 3       4  A31Bee3c201ef58    Yesenia   Martinez    23
# 4       5  1bA7A3dc874da3c       Lori       Todd    56
# ..    ...              ...        ...        ...   ...
# 94     96  5eFda7caAeB260E     Dennis     Barnes    64
# 95     97  CCbFce93d3720bE      Steve  Patterson    34
# 96     98  2fEc528aFAF0b69     Wesley       Bray    34
# 97     99  Adc7ad9B6e4A1Fe     Summer   Oconnell    22
# 98    100  b8D0aD3490FC7e1     Mariah    Bernard    21
#
#                          Email                   Phone Date of birth  \
# 0         elijah57@example.net  001-084-906-7849x73518    26-10-1945
# 1        bethany14@example.com       214.112.6044x4913    24-03-1910
# 2        bthompson@example.com            277.609.7938    02-07-1992
# ...

# %%
# set a new index  , as see new index is the email it took the place of the index
df.set_index('Email', inplace = True)

# %%
df
# Out:
#                             Index          User Id First Name  Last Name  \
# Email
# elijah57@example.net            1  88F7B33d2bcf9f5     Shelby    Terrell
# bethany14@example.com           2  f90cD3E76f1A9b9    Phillip    Summers
# bthompson@example.com           3  DbeAb8CcdfeFC2c   Kristine     Travis
# kaitlinkaiser@example.com       4  A31Bee3c201ef58    Yesenia   Martinez
# buchananmanuel@example.net      5  1bA7A3dc874da3c       Lori       Todd
# ...                           ...              ...        ...        ...
# bmartin@example.org            96  5eFda7caAeB260E     Dennis     Barnes
# latasha46@example.net          97  CCbFce93d3720bE      Steve  Patterson
# regina11@example.org           98  2fEc528aFAF0b69     Wesley       Bray
# alexiscantrell@example.org     99  Adc7ad9B6e4A1Fe     Summer   Oconnell
# pcopeland@example.org         100  b8D0aD3490FC7e1     Mariah    Bernard
#
#                             age                    Phone Date of birth  \
# Email
# ...

# %%
# if wanna original indexning back then do only
df.reset_index()
# here got  the origanl indexing back and the email is in first column
# Out:
#                          Email  Index          User Id First Name  Last Name  \
# 0         elijah57@example.net      1  88F7B33d2bcf9f5     Shelby    Terrell
# 1        bethany14@example.com      2  f90cD3E76f1A9b9    Phillip    Summers
# 2        bthompson@example.com      3  DbeAb8CcdfeFC2c   Kristine     Travis
# 3    kaitlinkaiser@example.com      4  A31Bee3c201ef58    Yesenia   Martinez
# 4   buchananmanuel@example.net      5  1bA7A3dc874da3c       Lori       Todd
# ..                         ...    ...              ...        ...        ...
# 94         bmartin@example.org     96  5eFda7caAeB260E     Dennis     Barnes
# 95       latasha46@example.net     97  CCbFce93d3720bE      Steve  Patterson
# 96        regina11@example.org     98  2fEc528aFAF0b69     Wesley       Bray
# 97  alexiscantrell@example.org     99  Adc7ad9B6e4A1Fe     Summer   Oconnell
# 98       pcopeland@example.org    100  b8D0aD3490FC7e1     Mariah    Bernard
#
# ...

# %%
# you can make data frame from the dictionary
d={'key1':[2,3,4],
   'key2':[5,6,7],
   'key3':[8,9,10]}

# %%
d
# Out:
# {'key1': [2, 3, 4], 'key2': [5, 6, 7], 'key3': [8, 9, 10]}

# %%
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     2     5     8
# 1     3     6     9
# 2     4     7    10

# %%
# tuple can also convert into the dataframe
d={'key1':(2,3,4),
   'key2':(5,6,7),
   'key3':(8,9,10)}

# %%
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     2     5     8
# 1     3     6     9
# 2     4     7    10

# %%
df
# Out:
#                             Index          User Id First Name  Last Name  \
# Email
# elijah57@example.net            1  88F7B33d2bcf9f5     Shelby    Terrell
# bethany14@example.com           2  f90cD3E76f1A9b9    Phillip    Summers
# bthompson@example.com           3  DbeAb8CcdfeFC2c   Kristine     Travis
# kaitlinkaiser@example.com       4  A31Bee3c201ef58    Yesenia   Martinez
# buchananmanuel@example.net      5  1bA7A3dc874da3c       Lori       Todd
# ...                           ...              ...        ...        ...
# bmartin@example.org            96  5eFda7caAeB260E     Dennis     Barnes
# latasha46@example.net          97  CCbFce93d3720bE      Steve  Patterson
# regina11@example.org           98  2fEc528aFAF0b69     Wesley       Bray
# alexiscantrell@example.org     99  Adc7ad9B6e4A1Fe     Summer   Oconnell
# pcopeland@example.org         100  b8D0aD3490FC7e1     Mariah    Bernard
#
#                             age                    Phone Date of birth  \
# Email
# ...

# %%
df.isnull().sum()
# there is no null value thats why it showing it zero else it will show the how many no. of null values are there like 11, 14, 15
# Out:
# Index            0
# User Id          0
# First Name       0
# Last Name        0
# age              0
# Phone            0
# Date of birth    0
# Job Title        0
# dtype: int64

# %%
pd.read_csv('mtt.csv')
# Out:
#                 model   mpg  cyl   disp     hp  drat     wt   qsec  vs   am  \
# 0           Mazda RX4  21.0  6.0  160.0  110.0  3.90  2.620  16.46   0  1.0
# 1       Mazda RX4 Wag  21.0  6.0  160.0  110.0  3.90  2.875  17.02   0  1.0
# 2          Datsun 710  22.8  NaN  108.0   93.0   NaN  2.320    NaN   1  1.0
# 3      Hornet 4 Drive  21.4  6.0  258.0  110.0  3.08  3.215    NaN   1  0.0
# 4   Hornet Sportabout  18.7  8.0  360.0  175.0  3.15  3.440    NaN   0  0.0
# 5             Valiant  18.1  6.0  225.0    NaN   NaN  3.460  20.22   1  NaN
# 6          Duster 360  14.3  NaN    NaN    NaN  3.21  3.570  15.84   0  0.0
# 7           Merc 240D  24.4  4.0  146.7   62.0  3.69  3.190  20.00   1  0.0
# 8            Merc 230  22.8  4.0  140.8   95.0  3.92  3.150  22.90   1  0.0
# 9            Merc 280  19.2  6.0  167.6  123.0   NaN  3.440  18.30   1  0.0
# 10          Merc 280C  17.8  6.0  167.6    NaN  3.92  3.440  18.90   1  0.0
# ...

# %%
df=(pd.read_csv('mtt.csv'))

# %%
df
# Out:
#                 model   mpg  cyl   disp     hp  drat     wt   qsec  vs   am  \
# 0           Mazda RX4  21.0  6.0  160.0  110.0  3.90  2.620  16.46   0  1.0
# 1       Mazda RX4 Wag  21.0  6.0  160.0  110.0  3.90  2.875  17.02   0  1.0
# 2          Datsun 710  22.8  NaN  108.0   93.0   NaN  2.320    NaN   1  1.0
# 3      Hornet 4 Drive  21.4  6.0  258.0  110.0  3.08  3.215    NaN   1  0.0
# 4   Hornet Sportabout  18.7  8.0  360.0  175.0  3.15  3.440    NaN   0  0.0
# 5             Valiant  18.1  6.0  225.0    NaN   NaN  3.460  20.22   1  NaN
# 6          Duster 360  14.3  NaN    NaN    NaN  3.21  3.570  15.84   0  0.0
# 7           Merc 240D  24.4  4.0  146.7   62.0  3.69  3.190  20.00   1  0.0
# 8            Merc 230  22.8  4.0  140.8   95.0  3.92  3.150  22.90   1  0.0
# 9            Merc 280  19.2  6.0  167.6  123.0   NaN  3.440  18.30   1  0.0
# 10          Merc 280C  17.8  6.0  167.6    NaN  3.92  3.440  18.90   1  0.0
# ...

# %%
df.isnull() # where obtaining the null values it shows the true
# Out:
#     model    mpg    cyl   disp     hp   drat     wt   qsec     vs     am  \
# 0   False  False  False  False  False  False  False  False  False  False
# 1   False  False  False  False  False  False  False  False  False  False
# 2   False  False   True  False  False   True  False   True  False  False
# 3   False  False  False  False  False  False  False   True  False  False
# 4   False  False  False  False  False  False  False   True  False  False
# 5   False  False  False  False   True   True  False  False  False   True
# 6   False  False   True   True   True  False  False  False  False  False
# 7   False  False  False  False  False  False  False  False  False  False
# 8   False  False  False  False  False  False  False  False  False  False
# 9   False  False  False  False  False   True  False  False  False  False
# 10  False  False  False  False   True  False  False  False  False  False
# 11  False  False  False   True  False  False  False  False  False  False
# ...

# %%
df.isnull().sum() # here showing the in which column having the null values are there
# Out:
# model    0
# mpg      0
# cyl      2
# disp     2
# hp       3
# drat     3
# wt       0
# qsec     3
# vs       0
# am       1
# gear     0
# carb     0
# dtype: int64

# %%
df.shape
# Out:
# (13, 12)

# %%
# remove all null values from the rows
df.dropna() # the rows are dropes whuch having the null values thats why here is showing the only 5 rows which didt have the null valiue
# Out:
#             model   mpg  cyl   disp     hp  drat     wt   qsec  vs   am  gear  \
# 0       Mazda RX4  21.0  6.0  160.0  110.0  3.90  2.620  16.46   0  1.0     4
# 1   Mazda RX4 Wag  21.0  6.0  160.0  110.0  3.90  2.875  17.02   0  1.0     4
# 7       Merc 240D  24.4  4.0  146.7   62.0  3.69  3.190  20.00   1  0.0     4
# 8        Merc 230  22.8  4.0  140.8   95.0  3.92  3.150  22.90   1  0.0     4
# 12     Merc 450SL  17.3  8.0  275.8  180.0  3.07  3.730  17.60   0  0.0     3
#
#     carb
# 0      4
# 1      4
# 7      2
# 8      2
# 12     3

# %%
# but when we wanna the drop the null value with their column then we will use
# axis=1 ---- that means you drop the column which havng the null value
# for dropping column it uses the axis=0...
df.dropna(axis=1)
# Out:
#                 model   mpg     wt  vs  gear  carb
# 0           Mazda RX4  21.0  2.620   0     4     4
# 1       Mazda RX4 Wag  21.0  2.875   0     4     4
# 2          Datsun 710  22.8  2.320   1     4     1
# 3      Hornet 4 Drive  21.4  3.215   1     3     1
# 4   Hornet Sportabout  18.7  3.440   0     3     2
# 5             Valiant  18.1  3.460   1     3     1
# 6          Duster 360  14.3  3.570   0     3     4
# 7           Merc 240D  24.4  3.190   1     4     2
# 8            Merc 230  22.8  3.150   1     4     2
# 9            Merc 280  19.2  3.440   1     4     4
# 10          Merc 280C  17.8  3.440   1     4     4
# 11         Merc 450SE  16.4  4.070   0     3     3
# 12         Merc 450SL  17.3  3.730   0     3     3

# %%
df.info
# Out:
# <bound method DataFrame.info of                 model   mpg  cyl   disp     hp  drat     wt   qsec  vs   am  \
# 0           Mazda RX4  21.0  6.0  160.0  110.0  3.90  2.620  16.46   0  1.0
# 1       Mazda RX4 Wag  21.0  6.0  160.0  110.0  3.90  2.875  17.02   0  1.0
# 2          Datsun 710  22.8  NaN  108.0   93.0   NaN  2.320    NaN   1  1.0
# 3      Hornet 4 Drive  21.4  6.0  258.0  110.0  3.08  3.215    NaN   1  0.0
# 4   Hornet Sportabout  18.7  8.0  360.0  175.0  3.15  3.440    NaN   0  0.0
# 5             Valiant  18.1  6.0  225.0    NaN   NaN  3.460  20.22   1  NaN
# 6          Duster 360  14.3  NaN    NaN    NaN  3.21  3.570  15.84   0  0.0
# 7           Merc 240D  24.4  4.0  146.7   62.0  3.69  3.190  20.00   1  0.0
# 8            Merc 230  22.8  4.0  140.8   95.0  3.92  3.150  22.90   1  0.0
# 9            Merc 280  19.2  6.0  167.6  123.0   NaN  3.440  18.30   1  0.0
# 10          Merc 280C  17.8  6.0  167.6    NaN  3.92  3.440  18.90   1  0.0
# ...

# %%
df.shape
# Out:
# (13, 12)

# %%
df.tail()
# Out:
#          model   mpg  cyl   disp     hp  drat    wt  qsec  vs   am  gear  carb
# 8     Merc 230  22.8  4.0  140.8   95.0  3.92  3.15  22.9   1  0.0     4     2
# 9     Merc 280  19.2  6.0  167.6  123.0   NaN  3.44  18.3   1  0.0     4     4
# 10   Merc 280C  17.8  6.0  167.6    NaN  3.92  3.44  18.9   1  0.0     4     4
# 11  Merc 450SE  16.4  8.0    NaN  180.0  3.07  4.07  17.4   0  0.0     3     3
# 12  Merc 450SL  17.3  8.0  275.8  180.0  3.07  3.73  17.6   0  0.0     3     3

# %%
df.head()
# Out:
#                model   mpg  cyl   disp     hp  drat     wt   qsec  vs   am  \
# 0          Mazda RX4  21.0  6.0  160.0  110.0  3.90  2.620  16.46   0  1.0
# 1      Mazda RX4 Wag  21.0  6.0  160.0  110.0  3.90  2.875  17.02   0  1.0
# 2         Datsun 710  22.8  NaN  108.0   93.0   NaN  2.320    NaN   1  1.0
# 3     Hornet 4 Drive  21.4  6.0  258.0  110.0  3.08  3.215    NaN   1  0.0
# 4  Hornet Sportabout  18.7  8.0  360.0  175.0  3.15  3.440    NaN   0  0.0
#
#    gear  carb
# 0     4     4
# 1     4     4
# 2     4     1
# 3     3     1
# 4     3     2

# %%
# imputation of missing values<<----replacing missing values with same values
# numeric data >>---- mean and median >> oulier (abnormal) value treatment is done , then use mean 
# categorical data  > mode
# impute missing with some constatnt , i.e -0

# %%
df
# Out:
#                 model   mpg  cyl   disp     hp  drat     wt   qsec  vs   am  \
# 0           Mazda RX4  21.0  6.0  160.0  110.0  3.90  2.620  16.46   0  1.0
# 1       Mazda RX4 Wag  21.0  6.0  160.0  110.0  3.90  2.875  17.02   0  1.0
# 2          Datsun 710  22.8  NaN  108.0   93.0   NaN  2.320    NaN   1  1.0
# 3      Hornet 4 Drive  21.4  6.0  258.0  110.0  3.08  3.215    NaN   1  0.0
# 4   Hornet Sportabout  18.7  8.0  360.0  175.0  3.15  3.440    NaN   0  0.0
# 5             Valiant  18.1  6.0  225.0    NaN   NaN  3.460  20.22   1  NaN
# 6          Duster 360  14.3  NaN    NaN    NaN  3.21  3.570  15.84   0  0.0
# 7           Merc 240D  24.4  4.0  146.7   62.0  3.69  3.190  20.00   1  0.0
# 8            Merc 230  22.8  4.0  140.8   95.0  3.92  3.150  22.90   1  0.0
# 9            Merc 280  19.2  6.0  167.6  123.0   NaN  3.440  18.30   1  0.0
# 10          Merc 280C  17.8  6.0  167.6    NaN  3.92  3.440  18.90   1  0.0
# ...

# %%
df.fillna("somevalue")
# it use when the there is some missing values are there it strt to print there is somevalue 
# we can write there anything we wanna to
# Out:
#                 model   mpg        cyl       disp         hp       drat  \
# 0           Mazda RX4  21.0        6.0      160.0      110.0        3.9
# 1       Mazda RX4 Wag  21.0        6.0      160.0      110.0        3.9
# 2          Datsun 710  22.8  somevalue      108.0       93.0  somevalue
# 3      Hornet 4 Drive  21.4        6.0      258.0      110.0       3.08
# 4   Hornet Sportabout  18.7        8.0      360.0      175.0       3.15
# 5             Valiant  18.1        6.0      225.0  somevalue  somevalue
# 6          Duster 360  14.3  somevalue  somevalue  somevalue       3.21
# 7           Merc 240D  24.4        4.0      146.7       62.0       3.69
# 8            Merc 230  22.8        4.0      140.8       95.0       3.92
# 9            Merc 280  19.2        6.0      167.6      123.0  somevalue
# 10          Merc 280C  17.8        6.0      167.6  somevalue       3.92
# 11         Merc 450SE  16.4        8.0  somevalue      180.0       3.07
# ...

# %%
df.fillna("fillmissingvalue") 
# now here we put the filllmissingvalue ehre the null value was there
# Out:
#                 model   mpg               cyl              disp  \
# 0           Mazda RX4  21.0               6.0             160.0
# 1       Mazda RX4 Wag  21.0               6.0             160.0
# 2          Datsun 710  22.8  fillmissingvalue             108.0
# 3      Hornet 4 Drive  21.4               6.0             258.0
# 4   Hornet Sportabout  18.7               8.0             360.0
# 5             Valiant  18.1               6.0             225.0
# 6          Duster 360  14.3  fillmissingvalue  fillmissingvalue
# 7           Merc 240D  24.4               4.0             146.7
# 8            Merc 230  22.8               4.0             140.8
# 9            Merc 280  19.2               6.0             167.6
# 10          Merc 280C  17.8               6.0             167.6
# 11         Merc 450SE  16.4               8.0  fillmissingvalue
# 12         Merc 450SL  17.3               8.0             275.8
#
# ...

# %%
# also we can replace it by the zero 
df.fillna(0)
# Out:
#                 model   mpg  cyl   disp     hp  drat     wt   qsec  vs   am  \
# 0           Mazda RX4  21.0  6.0  160.0  110.0  3.90  2.620  16.46   0  1.0
# 1       Mazda RX4 Wag  21.0  6.0  160.0  110.0  3.90  2.875  17.02   0  1.0
# 2          Datsun 710  22.8  0.0  108.0   93.0  0.00  2.320   0.00   1  1.0
# 3      Hornet 4 Drive  21.4  6.0  258.0  110.0  3.08  3.215   0.00   1  0.0
# 4   Hornet Sportabout  18.7  8.0  360.0  175.0  3.15  3.440   0.00   0  0.0
# 5             Valiant  18.1  6.0  225.0    0.0  0.00  3.460  20.22   1  0.0
# 6          Duster 360  14.3  0.0    0.0    0.0  3.21  3.570  15.84   0  0.0
# 7           Merc 240D  24.4  4.0  146.7   62.0  3.69  3.190  20.00   1  0.0
# 8            Merc 230  22.8  4.0  140.8   95.0  3.92  3.150  22.90   1  0.0
# 9            Merc 280  19.2  6.0  167.6  123.0  0.00  3.440  18.30   1  0.0
# 10          Merc 280C  17.8  6.0  167.6    0.0  3.92  3.440  18.90   1  0.0
# ...

# %%
data1 = {
    'A':[1,2,None,4,5,None,7,8,9,10],
    'B':[None,11,12,13,None,15,16,None,18,19]
}
df2= pd.DataFrame(data1)
df2
# Out:
#       A     B
# 0   1.0   NaN
# 1   2.0  11.0
# 2   NaN  12.0
# 3   4.0  13.0
# 4   5.0   NaN
# 5   NaN  15.0
# 6   7.0  16.0
# 7   8.0   NaN
# 8   9.0  18.0
# 9  10.0  19.0

# %%
# if you want to replace the missing value with the mean value
df2['A'].mean()
# Out:
# 5.75

# %%
df2['A']
# Out:
# 0     1.0
# 1     2.0
# 2     NaN
# 3     4.0
# 4     5.0
# 5     NaN
# 6     7.0
# 7     8.0
# 8     9.0
# 9    10.0
# Name: A, dtype: float64

# %%
df2['A'].fillna(df2['A'].mean())
# here we fill the value of mean value
# Out:
# 0     1.00
# 1     2.00
# 2     5.75
# 3     4.00
# 4     5.00
# 5     5.75
# 6     7.00
# 7     8.00
# 8     9.00
# 9    10.00
# Name: A, dtype: float64

# %%
# we can replace it by the median also
df2['A'].median()
# Out:
# 6.0

# %%
df2.fillna("some value")
# Out:
#             A           B
# 0         1.0  some value
# 1         2.0        11.0
# 2  some value        12.0
# 3         4.0        13.0
# 4         5.0  some value
# 5  some value        15.0
# 6         7.0        16.0
# 7         8.0  some value
# 8         9.0        18.0
# 9        10.0        19.0

# %%
df2.fillna(method="ffill") # here it will fill the value which is theprivious value 
#start seeing from the botom of the data fill
# Out:
# C:\Users\Ashwini Powar\AppData\Local\Temp\ipykernel_14404\2502807920.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df2.fillna(method="ffill") # here it will fill the value which is theprivious value
#       A     B
# 0   1.0   NaN
# 1   2.0  11.0
# 2   2.0  12.0
# 3   4.0  13.0
# 4   5.0  13.0
# 5   5.0  15.0
# 6   7.0  16.0
# 7   8.0  16.0
# 8   9.0  18.0
# 9  10.0  19.0

# %%
df2.fillna(method="bfill") # next line word will print in the peivious where having the nan value was
# backward fill>>
# Out:
# C:\Users\Ashwini Powar\AppData\Local\Temp\ipykernel_14404\90801012.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df2.fillna(method="bfill")
#       A     B
# 0   1.0  11.0
# 1   2.0  11.0
# 2   4.0  12.0
# 3   4.0  13.0
# 4   5.0  15.0
# 5   7.0  15.0
# 6   7.0  16.0
# 7   8.0  18.0
# 8   9.0  18.0
# 9  10.0  19.0

# %%
# checking duplicated row
df2.duplicated().sum()
# Out:
# 0

# %%
df
# Out:
#                 model   mpg  cyl   disp     hp  drat     wt   qsec  vs   am  \
# 0           Mazda RX4  21.0  6.0  160.0  110.0  3.90  2.620  16.46   0  1.0
# 1       Mazda RX4 Wag  21.0  6.0  160.0  110.0  3.90  2.875  17.02   0  1.0
# 2          Datsun 710  22.8  NaN  108.0   93.0   NaN  2.320    NaN   1  1.0
# 3      Hornet 4 Drive  21.4  6.0  258.0  110.0  3.08  3.215    NaN   1  0.0
# 4   Hornet Sportabout  18.7  8.0  360.0  175.0  3.15  3.440    NaN   0  0.0
# 5             Valiant  18.1  6.0  225.0    NaN   NaN  3.460  20.22   1  NaN
# 6          Duster 360  14.3  NaN    NaN    NaN  3.21  3.570  15.84   0  0.0
# 7           Merc 240D  24.4  4.0  146.7   62.0  3.69  3.190  20.00   1  0.0
# 8            Merc 230  22.8  4.0  140.8   95.0  3.92  3.150  22.90   1  0.0
# 9            Merc 280  19.2  6.0  167.6  123.0   NaN  3.440  18.30   1  0.0
# 10          Merc 280C  17.8  6.0  167.6    NaN  3.92  3.440  18.90   1  0.0
# ...

# %%
df.std
# Out:
# <bound method DataFrame.std of                 model   mpg  cyl   disp     hp  drat     wt   qsec  vs   am  \
# 0           Mazda RX4  21.0  6.0  160.0  110.0  3.90  2.620  16.46   0  1.0
# 1       Mazda RX4 Wag  21.0  6.0  160.0  110.0  3.90  2.875  17.02   0  1.0
# 2          Datsun 710  22.8  NaN  108.0   93.0   NaN  2.320    NaN   1  1.0
# 3      Hornet 4 Drive  21.4  6.0  258.0  110.0  3.08  3.215    NaN   1  0.0
# 4   Hornet Sportabout  18.7  8.0  360.0  175.0  3.15  3.440    NaN   0  0.0
# 5             Valiant  18.1  6.0  225.0    NaN   NaN  3.460  20.22   1  NaN
# 6          Duster 360  14.3  NaN    NaN    NaN  3.21  3.570  15.84   0  0.0
# 7           Merc 240D  24.4  4.0  146.7   62.0  3.69  3.190  20.00   1  0.0
# 8            Merc 230  22.8  4.0  140.8   95.0  3.92  3.150  22.90   1  0.0
# 9            Merc 280  19.2  6.0  167.6  123.0   NaN  3.440  18.30   1  0.0
# 10          Merc 280C  17.8  6.0  167.6    NaN  3.92  3.440  18.90   1  0.0
# ...

# %%
#
