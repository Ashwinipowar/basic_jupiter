# %%
import pandas as pd

# %%
pd.read_csv("customers-100.csv")
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
df=(pd.read_csv("customers-100.csv"))

# %%
df
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
df.columns
# Out:
# Index(['Index', 'Customer Id', 'First Name', 'Last Name', 'Company', 'City',
#        'Country', 'Phone 1', 'Phone 2', 'Email', 'Subscription Date',
#        'Website'],
#       dtype='object')

# %%
df.head()
# Out:
#    Index      Customer Id First Name Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
#
#                       Country                 Phone 1                Phone 2  \
# 0                       Chile            229.077.5154       397.884.0519x718
# 1                    Djibouti              5153435776       686-620-1820x944
# 2         Antigua and Barbuda         +1-539-402-0259    (496)978-3969x58947
# ...

# %%
df.tail()
# Out:
#     Index      Customer Id First Name Last Name                Company  \
# 95     96  cb8E23e48d22Eae       Karl     Greer              Carey LLC
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson  Ware, Burns and Oneal
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra          Schmitt-Jones
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer     Fitzgerald-Harrell
# 99    100  2354a0E336A91A1   Clarence    Haynes     Le, Nash and Cross
#
#                City          Country               Phone 1  \
# 95     East Richard           Guyana   (188)169-1674x58692
# 96     New Bradview        Sri Lanka       +1-846-706-2218
# 97       Ortegaland  Solomon Islands  +1-753-067-8419x7170
# 98  Lake Elijahview            Aruba         (530)311-9786
# 99        Judymouth         Honduras         (753)813-6941
#
#                    Phone 2                           Email Subscription Date  \
# 95    001-841-293-3519x614                hhart@jensen.com        2022-01-30
# ...

# %%
df.dtypes
# Out:
# Index                 int64
# Customer Id          object
# First Name           object
# Last Name            object
# Company              object
# City                 object
# Country              object
# Phone 1              object
# Phone 2              object
# Email                object
# Subscription Date    object
# Website              object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Index              100 non-null    int64
#  1   Customer Id        100 non-null    object
#  2   First Name         100 non-null    object
#  3   Last Name          100 non-null    object
#  4   Company            100 non-null    object
#  5   City               100 non-null    object
#  6   Country            100 non-null    object
#  7   Phone 1            100 non-null    object
#  8   Phone 2            100 non-null    object
#  9   Email              100 non-null    object
#  10  Subscription Date  100 non-null    object
#  11  Website            100 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 9.5+ KB

# %%
df.describe()# staistical info about numerical column
# Out:
#             Index
# count  100.000000
# mean    50.500000
# std     29.011492
# min      1.000000
# 25%     25.750000
# 50%     50.500000
# 75%     75.250000
# max    100.000000

# %%
# five point summury>> min, 25% , 50%, 75%, max

# %%
# when wanna subset of data
df[["City", "Country" ,"Company"]]
# Out:
#                  City                     Country  \
# 0        East Leonard                       Chile
# 1   East Jimmychester                    Djibouti
# 2       Isabelborough         Antigua and Barbuda
# 3          Bensonview          Dominican Republic
# 4      West Priscilla  Slovakia (Slovak Republic)
# ..                ...                         ...
# 95       East Richard                      Guyana
# 96       New Bradview                   Sri Lanka
# 97         Ortegaland             Solomon Islands
# 98    Lake Elijahview                       Aruba
# 99          Judymouth                    Honduras
#
#                             Company
# 0                   Rasmussen Group
# 1                       Vega-Gentry
# 2                     Murillo-Perry
# 3   Dominguez, Mcmillan and Donovan
# 4          Martin, Lang and Andrade
# ..                              ...
# 95                        Carey LLC
# 96            Ware, Burns and Oneal
# ...

# %%
df.dtypes
# Out:
# Index                 int64
# Customer Id          object
# First Name           object
# Last Name            object
# Company              object
# City                 object
# Country              object
# Phone 1              object
# Phone 2              object
# Email                object
# Subscription Date    object
# Website              object
# dtype: object

# %%
# if you wanna a column name which are the objects
df.dtypes=="object"# object is a string datatype # printing the true where object were present
# Out:
# Index                False
# Customer Id           True
# First Name            True
# Last Name             True
# Company               True
# City                  True
# Country               True
# Phone 1               True
# Phone 2               True
# Email                 True
# Subscription Date     True
# Website               True
# dtype: bool

# %%
df.dtypes[df.dtypes=="object"]# returns only those value where condition is true
# Out:
# Customer Id          object
# First Name           object
# Last Name            object
# Company              object
# City                 object
# Country              object
# Phone 1              object
# Phone 2              object
# Email                object
# Subscription Date    object
# Website              object
# dtype: object

# %%
#to get the index
df.dtypes[df.dtypes=="object"].index # these are the actully string column
# Out:
# Index(['Customer Id', 'First Name', 'Last Name', 'Company', 'City', 'Country',
#        'Phone 1', 'Phone 2', 'Email', 'Subscription Date', 'Website'],
#       dtype='object')

# %%
df[df.dtypes[df.dtypes=="object"].index]# string data
# Out:
#         Customer Id First Name Last Name                          Company  \
# 0   DD37Cf93aecA6Dc     Sheryl    Baxter                  Rasmussen Group
# 1   1Ef7b82A4CAAD10    Preston    Lozano                      Vega-Gentry
# 2   6F94879bDAfE5a6        Roy     Berry                    Murillo-Perry
# 3   5Cef8BFA16c5e3c      Linda     Olsen  Dominguez, Mcmillan and Donovan
# 4   053d585Ab6b3159     Joanna    Bender         Martin, Lang and Andrade
# ..              ...        ...       ...                              ...
# 95  cb8E23e48d22Eae       Karl     Greer                        Carey LLC
# 96  CeD220bdAaCfaDf       Lynn  Atkinson            Ware, Burns and Oneal
# 97  28CDbC0dFe4b1Db       Fred    Guerra                    Schmitt-Jones
# 98  c23d1D9EE8DEB0A     Yvonne    Farmer               Fitzgerald-Harrell
# 99  2354a0E336A91A1   Clarence    Haynes               Le, Nash and Cross
#
#                  City                     Country                 Phone 1  \
# ...

# %%
#numerical data
df[df.dtypes[df.dtypes!="object"].index]
# Out:
#     Index
# 0       1
# 1       2
# 2       3
# 3       4
# 4       5
# ..    ...
# 95     96
# 96     97
# 97     98
# 98     99
# 99    100
#
# [100 rows x 1 columns]

# %%
#when wnats to describe the numerical data
df[df.dtypes[df.dtypes!="object"].index].describe() # write a correct describe name dont make any spelling mistake
# Out:
#             Index
# count  100.000000
# mean    50.500000
# std     29.011492
# min      1.000000
# 25%     25.750000
# 50%     50.500000
# 75%     75.250000
# max    100.000000

# %%
df.describe()# numerical column
# Out:
#             Index
# count  100.000000
# mean    50.500000
# std     29.011492
# min      1.000000
# 25%     25.750000
# 50%     50.500000
# 75%     75.250000
# max    100.000000

# %%
df.describe(include ="object")# for the uniqueness of the evry column
# Out:
#             Customer Id First Name Last Name    Company          City  \
# count               100        100       100        100           100
# unique              100         93        97         99           100
# top     DD37Cf93aecA6Dc     Sheryl     Greer  Simon LLC  East Leonard
# freq                  1          2         2          2             1
#
#                 Country       Phone 1           Phone 2  \
# count               100           100               100
# unique               85           100               100
# top     Solomon Islands  229.077.5154  397.884.0519x718
# freq                  4             1                 1
#
#                            Email Subscription Date                     Website
# count                        100               100                         100
# unique                       100                96                         100
# top     zunigavanessa@smith.info        2021-12-02  http://www.stephenson.com/
# ...

# %%
# all info murge together
df.describe(include ="all")
# Out:
#              Index      Customer Id First Name Last Name    Company  \
# count   100.000000              100        100       100        100
# unique         NaN              100         93        97         99
# top            NaN  DD37Cf93aecA6Dc     Sheryl     Greer  Simon LLC
# freq           NaN                1          2         2          2
# mean     50.500000              NaN        NaN       NaN        NaN
# std      29.011492              NaN        NaN       NaN        NaN
# min       1.000000              NaN        NaN       NaN        NaN
# 25%      25.750000              NaN        NaN       NaN        NaN
# 50%      50.500000              NaN        NaN       NaN        NaN
# 75%      75.250000              NaN        NaN       NaN        NaN
# max     100.000000              NaN        NaN       NaN        NaN
#
#                 City          Country       Phone 1           Phone 2  \
# count            100              100           100               100
# ...

# %%
df.shape#100 rows and 12 column
# Out:
# (100, 12)

# %%
#when wanna aceess 0 to 100 row 
df[0:100]
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
# when wnats after every fifth element
df[0:100:5]# distance will be 0,5,10, 15 like that
# Out:
#     Index      Customer Id  First Name   Last Name  \
# 0       1  DD37Cf93aecA6Dc      Sheryl      Baxter
# 5       6  2d08FB17EE273F4       Aimee       Downs
# 10     11  216E205d6eBb815        Carl   Schroeder
# 15     16  8cad0b4CBceaeec     Miranda     Beasley
# 20     21  9F9AdB7B8A6f7F2     Maxwell        Frye
# 25     26  09D7D7C8Fe09aea      Marcus       Moody
# 30     31  64DCcDFaB9DFd4e        Jack        Tate
# 35     36  E11dfb2DB8C9f72      Tammie       Haley
# 40     41  2f79Cd309624Abb     Natalie      Gentry
# 45     46  fD780ED8dbEae7B      Joanne      Montes
# 50     51  Aa20BDe68eAb0e9      Gerald     Hawkins
# 55     56  C6F2Fc6a7948a4e       Ralph        Haas
# 60     61  a940cE42e035F28        Lynn        Pham
# 65     66  fF1b6c9E8Fbf1ff    Fernando     Lambert
# 70     71  CBCd2Ac8E3eBDF9  Alexandria        Buck
# 75     76  d40e89dCade7b2F       Debra      Riddle
# 80     81  D6CEAfb3BDbaa1A      Leslie    Jennings
# ...

# %%
df.astype('object').describe()
# Out:
#         Index      Customer Id First Name Last Name    Company          City  \
# count     100              100        100       100        100           100
# unique    100              100         93        97         99           100
# top         1  DD37Cf93aecA6Dc     Sheryl     Greer  Simon LLC  East Leonard
# freq        1                1          2         2          2             1
#
#                 Country       Phone 1           Phone 2  \
# count               100           100               100
# unique               85           100               100
# top     Solomon Islands  229.077.5154  397.884.0519x718
# freq                  4             1                 1
#
#                            Email Subscription Date                     Website
# count                        100               100                         100
# unique                       100                96                         100
# ...

# %%
#for adding the new column, data name is pwskills and col name is new_column
df["new_col"] = "pwskills"

# %%
df
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
# when create a new column from the existing column
#......df["family"] = df["index"]+df["Customer_id"]..... # not run bcz having no data for adding two will show in three like 1+2=3

# %%
df.info
# Out:
# <bound method DataFrame.info of     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
df['City'].unique() # showing the unique value which is in the present
# Out:
# array(['East Leonard', 'East Jimmychester', 'Isabelborough', 'Bensonview',
#        'West Priscilla', 'Chavezborough', 'Lake Ana', 'Kimport',
#        'Robersonstad', 'Elaineberg', 'Shannonville', 'East Andrea',
#        'South Joannamouth', 'Jodyberg', 'Burchbury', 'Desireeshire',
#        'West Adriennestad', 'Lake Leslie', 'Harmonview', 'Jamesshire',
#        'East Carly', 'South Alvin', 'Brittanyview', 'Veronicamouth',
#        'Bryanville', 'Kaitlyntown', 'Michealshire', 'South Marissatown',
#        'Acevedoville', 'North Harold', 'West Samuel', 'Cunninghamborough',
#        'Port Annatown', 'New Kaitlyn', 'West Marthaburgh', 'East Teresa',
#        'South Hunter', 'South Walter', 'Poolefurt', 'West John',
#        'West Darius', 'North Jimstad', 'East Rebekahborough',
#        'North Drew', 'Lake Lindaburgh', 'Gwendolynview', 'Zimmermanland',
#        'North Kerriton', 'North Eileenville', 'Port Sergiofort',
# ...

# %%
df['Email'].unique()
# Out:
# array(['zunigavanessa@smith.info', 'vmata@colon.com',
#        'beckycarr@hogan.com', 'stanleyblackwell@benson.org',
#        'colinalvarado@miles.net', 'louis27@gilbert.com',
#        'tgates@cantrell.com', 'asnow@colon.com',
#        'mariokhan@ryan-pope.org', 'mdyer@escobar.net',
#        'kirksalas@webb.com', 'mark42@robbins.com', 'alex56@walls.org',
#        'holdenmiranda@clarke.com', 'cassieparrish@blevins-chapman.net',
#        'vduncan@parks-hardy.com', 'holtgwendolyn@watson-davenport.com',
#        'jaredjuarez@carroll.org', 'joseph26@jacobson.com',
#        'tuckerangie@salazar.net', 'fgibson@drake-webb.com',
#        'blanchardbob@wallace-shannon.com', 'rsingleton@ryan-cherry.com',
#        'stefanie71@spence.com', 'mariah88@santos.com',
#        'donnamullins@norris-barrett.org', 'stacey67@fields.org',
#        'jacobkhan@bright.biz', 'wterrell@clark.com', 'qjimenez@boyd.com',
#        'gfigueroa@boone-zavala.com', 'tapiagreg@beard.info',
# ...

# %%
# when wanna to count the unique value or we can say find how many no. of unique value are present in there
df['City'].nunique()
# Out:
# 100

# %%
# here we find the company which are repeated 
df['Company'].value_counts()
# Out:
# Company
# Simon LLC                      2
# Rasmussen Group                1
# Knight, Abbott and Hubbard     1
# Parrish Ltd                    1
# Huynh and Sons                 1
#                               ..
# Mcgee Group                    1
# Acosta, Petersen and Morrow    1
# Sawyer PLC                     1
# Santana-Duran                  1
# Le, Nash and Cross             1
# Name: count, Length: 99, dtype: int64

# %%
df['City'].value_counts()
# Out:
# City
# East Leonard         1
# South Julia          1
# Skinnerport          1
# East Summerstad      1
# New Jasmineshire     1
#                     ..
# West Samuel          1
# North Harold         1
# Acevedoville         1
# South Marissatown    1
# Judymouth            1
# Name: count, Length: 100, dtype: int64

# %%
#how many percent of city are there, here is 1.0 percent each company is there
df['City'].value_counts(normalize=True)*100
# Out:
# City
# East Leonard         1.0
# South Julia          1.0
# Skinnerport          1.0
# East Summerstad      1.0
# New Jasmineshire     1.0
#                     ...
# West Samuel          1.0
# North Harold         1.0
# Acevedoville         1.0
# South Marissatown    1.0
# Judymouth            1.0
# Name: proportion, Length: 100, dtype: float64

# %%
# if we had age then we can also  find blow something date aur above something
#...........df[df['age']<5]........

# %%
#df[df['age']<5].shape .....then also can find the no.of rows and no. of columnss ex (40,14) # 40 people whi are less than 5 year old
#df[df['age']<5].name ----- for the print there name who are below thw 5 year old

# %%
df['Index'].mean() # for finding the mean of any data ex of age --- wants to mean
# Out:
# 50.5

# %%
# how many male passangers are there
#----len(df[df['sex'] =="male"---
# Out:
# <function len(obj, /)>
